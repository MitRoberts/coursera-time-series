# %% [markdown]
# # Time Series Coursera

# %% [markdown]
# ## Week 1

# %% [markdown]
# ### Summary Statistics

# %% [markdown]
# c() is the concatenation operator for r, this is how you stick datasets together.

# %%
data.1=c(35, 8, 10, 23, 42)
print(data.1)
# Out:
# [1] 35  8 10 23 42

# %% [markdown]
# There are ways to get the summary statistics using summary() or single statistics such as mean or standard deviation.

# %%
summary(data.1)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     8.0    10.0    23.0    23.6    35.0    42.0

# %%
mean(data.1)
# Out:
# [1] 23.6

# %%
sd(data.1)
# Out:
# [1] 14.97665

# %% [markdown]
# ### Histograms

# %% [markdown]
# R is able to do nice histograms, which you can customise.

# %%
small.size.dataset=c(91,49,76,112,97,42,70, 100, 8, 112, 95, 90, 78, 62, 56, 94, 65, 58, 109, 70, 109, 91, 71, 76, 68, 62, 134, 57, 83, 66)

# %%
hist(small.size.dataset, xlab='My data points', main='Histogram of my data', freq=F, col='green', breaks=10)
lines(density(small.size.dataset), col='red', lwd=5)
# Out:
# Plot with title "Histogram of my data"

# %% [markdown]
# ### Scatterplots

# %% [markdown]
# Its fairly easy to do scatterplots

# %%
set.seed=2016
Test_1_scores=round(rnorm(50,78,10))
Test_2_scores=round(rnorm(50,70,14))
Test_1_scores
# Out:
#  [1] 83 53 74 74 67 72 68 84 81 81 67 89 90 74 79 74 93 53 79 87 90 91 75 83 71
# [26] 65 84 80 76 79 87 84 88 82 67 98 78 86 90 89 67 64 69 72 57 72 77 77 56 76

# %%
plot(Test_2_scores, Test_1_scores, main='Test scores for two exams (50 students)', xlab='Test 1 scores', ylab='Test 2 scores', col='blue')
# Out:
# Plot with title "Test scores for two exams (50 students)"

# %% [markdown]
# ### Mauna Loa Atmospheric co2 Concentration Excersise

# %% [markdown]
# Its important that the data we deal with is classed as a time series

# %%
class(co2) # shows as a ts class
# Out:
# [1] "ts"

# %%
plot(co2, main='Atmospheric CO2 Concentration')
# Out:
# [1] "ts"
# Plot with title "Atmospheric CO2 Concentration"

# %% [markdown]
# CO2 concentration is apparently increasing with time over this period. Also, even though a straight line obviously misses some crucial behavior it isn’t entirely useless in that it can be used to model the trend in the data.

# %% [markdown]
# #### Linear model of data

# %%
co2.linear.model = lm(co2 ~ time(co2))

# %%
plot(co2, main='Atmospheric CO2 Concentration with Fitted Line') 
abline(co2.linear.model )
# Out:
# Plot with title "Atmospheric CO2 Concentration with Fitted Line"

# %% [markdown]
# Its important to note that there are 3 assumptions for the errors (residuals) when fitting linear models.
#     - normal distribution
#     - same variance over the x value
#     - errors are uncorrelated

# %%
( co2.residuals = resid( co2.linear.model ) )
# Out:
#            1            2            3            4            5            6
#  3.808180799  4.589222742  4.670264684  5.621306627  6.082348569  5.843390511
#            7            8            9           10           11           12
#  4.124432454  2.275474396  1.196516339  0.587558281  1.958600224  2.619642166
#           13           14           15           16           17           18
#  3.350684109  3.781726051  4.282767993  5.623809936  6.514851878  5.965893821
#           19           20           21           22           23           24
#  4.436935763  2.057977706  0.209019648 -0.219938409  0.831103533  1.912145475
#           25           26           27           28           29           30
#  2.503187418  3.204229360  3.935271303  4.756313245  5.757355188  4.838397130
#  1.355783387  2.296825329  2.867867272  3.568909214  4.419951157  3.380993099
#          379          380          381          382          383          384
#  1.872035042 -0.146923016 -2.195881074 -2.084839131 -0.543797189  0.727244754
#          385          386          387          388          389          390
#  1.138286696  2.069328639  3.360370581  4.701412523  5.332454466  4.123496408
#          391          392          393          394          395          396
#  1.954538351 -0.294419707 -2.273377764 -2.322335822 -0.901293879  0.239748063
#          397          398          399          400          401          402
#  1.120790005  1.761831948  2.742873890  3.983915833  4.384957775  3.865999718
#          403          404          405          406          407          408
#  1.527041660 -0.601916397 -2.690874455 -2.509832513 -1.758790570 -0.627748628
#          409          410          411          412          413          414
#  0.563293315  0.924335257  2.035377200  3.016419142  3.727461084  2.938503027
#          415          416          417          418          419          420
#  0.809544969 -1.349413088 -3.268371146 -3.097329203 -1.856287261 -0.485245318
#          421          422          423          424          425          426
#  0.965796624  1.406838566  2.357880509  3.548922451  3.859964394  3.021006336
#          427          428          429          430          431          432
#  1.522048279 -0.646909779 -2.405867837 -2.354825894 -0.873783952  0.477257991
#          433          434          435          436          437          438
#  1.298299933  2.239341876  2.760383818  4.471425761  4.702467703  4.073509645
#          439          440          441          442          443          444
#  2.604551588  0.055593530 -1.443364527 -1.862322585 -0.161280642  0.859761300
#          445          446          447          448          449          450
#  2.100803243  3.191845185  3.852887127  4.443929070  5.024971012  4.476012955
#          451          452          453          454          455          456
#  3.057054897  0.788096840 -1.350861218 -1.319819276 -0.278777333  1.192264609
#          457          458          459          460          461          462
#  1.933306552  2.654348494  3.095390437  4.776432379  5.107474322  3.838516264
#          463          464          465          466          467          468
#  2.569558206  0.510600149 -1.928357909 -1.447315966  0.103725976  1.844767919

# %%
par(mfrow=c(1,3)) 
hist(co2.residuals, main= "Histogram of CO2 Residuals")
qqnorm(co2.residuals, main= "Normal Probability Plot")
qqline(co2.residuals)
plot(co2.residuals ~ time(co2), main="Residuals on Time")
# Out:
# Plot with title "Residuals on Time"

# %%
plot(co2.residuals ~ time(co2), xlim=c(1960, 1963), main="Zoomed in Residuals on Time")
# Out:
# Plot with title "Zoomed in Residuals on Time"

# %%
plot(extra~group, data=sleep, main = "Extra Sleep in Gossett Data by Group")
# Out:
# Plot with title "Extra Sleep in Gossett Data by Group"

# %%
attach(sleep)
# Out:
# The following objects are masked from sleep (pos = 3):
#
#     extra, group, ID

# %%
extra.1=extra[group==1] 
extra.2=extra[group==2]

# %%
t.test(extra.1, extra.2, paired=TRUE, alternative="two.sided")
# Out:
# 	Paired t-test
#
# data:  extra.1 and extra.2
# t = -4.0621, df = 9, p-value = 0.002833
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.4598858 -0.7001142
# sample estimates:
# mean of the differences
#                   -1.58

# %%
diffs = extra.1-extra.2 
qqnorm(diffs, main= "Normal Probability Plot") 
qqline(diffs)
# Out:
# Plot with title "Normal Probability Plot"

# %%
plot(extra.2~extra.1, xlab='extra sleep with drug 1',  ylab='extra sleep with drug 2' ,  main='Extra Sleep Drug 2 against Extra Sleep Drug 1')
sleep.linear.model = lm(extra.2 ~ extra.1 )
abline(sleep.linear.model)
# Out:
# Plot with title "Extra Sleep Drug 2 against Extra Sleep Drug 1"
